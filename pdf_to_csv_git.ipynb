# %%
# pip install pdfminer.six --trusted-host pypi.python.org --trusted-host pypi.org --trusted-host=files.pythonhosted.org

# %%
# pip install pdfplumber --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host=files.pythonhosted.org

# %%
import pandas as pd 
import re
from pdfminer.high_level import extract_text

# %%
# Import PDF
text = extract_text('C:\\Users\\fatogunt\\Downloads\\AA731NYC_ASMT.pdf')

# Split text into records
error_records = text.split('\n\n')  

# Process records by splitting based on the pipe ('|') character
parids = []
taxyrs = []  
jurs = []
procedures = []
errmsgs = []

# Process each record
record_lines = []
for record in error_records[1:]:  # Skip the first line (column titles)
    # Check if the line contains '-----', a date, or is empty; if yes, skip
    if '-----' in record or any(char.isdigit() for char in record) or not record.strip():
        print(f"Skipping record: {record}")
        continue
    
    # Concatenate lines until a complete record is obtained
    while '|' not in record:
        record += next(error_records[1:], '')  # Concatenate with the next line

    # Split the record into fields based on the pipe ('|') character
    fields = record.split('|')

    # Check if the number of fields is correct (assuming at least 5 fields)
    if len(fields) >= 5:
        # Extract and process the fields
        parids.append(fields[0].strip())
        taxyrs.append(fields[1].strip())
        jurs.append(fields[2].strip())
        procedures.append(fields[3].strip())
        errmsgs.append(fields[4].strip())
    else:
        # Handle cases where the record does not match the expected structure
        print(f"Skipping record (incorrect structure): {record}")

# Create the DataFrame  
df = pd.DataFrame({
    'PARID': parids, 
    'TAXYR': taxyrs,
    'JUR': jurs,
    'PROCEDURE': procedures,  
    'ERRMSG': errmsgs
})

# Print the first few rows of the DataFrame, excluding records with incorrect structure
print(df[df['PARID'] != 'PARID'].head())

# Save DataFrame to CSV
df.to_csv('error_log.csv', index=False)
# Out:
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
# 1000110014| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100011001400000001-0000
#           |     |   |                               |4)
# Skipping record: 1000110014| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100011001400000001-0000
#           |     |   |                               |7)
# Skipping record: 1000161437| 2016|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.
# 1000161547| 2015|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.
# 1000161555| 2016|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.
# 1000161594| 2015|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.
# 1000161595| 2015|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.
# 1000161596| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000162292| 2023|65 |Asmt before row Trig.          |ORA-00001: unique constraint (IAS.ASMT_H) violated
# 1000165012| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1000165012| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1000165678| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1000165678| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1000165707| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000166044| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000166044| 2022|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000166128| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000166128| 2022|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000168058| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000168058| 2022|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000168147| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000168147| 2022|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000181009| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000181088| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000411210| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411212| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411218| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411235| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411237| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411245| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411247| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41836 not allowed with 421G
# 1000411259| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411263| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411269| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411277| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411278| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000411288| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000531023| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000640008| 2021|65 |CALCXMPNY.CALCPAR_NYC          |STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 13B. Unit
#           |     |   |                               |(100064000800000001-0000    13B)
# Skipping record: 1000651001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 4B. Unit
#           |     |   |                               |(100065100100000001-0000     4B)
# Skipping record: 1000761156| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000761331| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000761424| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1000781601| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781602| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781603| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781604| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781605| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781606| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781607| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781608| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781609| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# Skipping record:
#
#
#
#
# 04-DEC-2023 08:59:36 PM                                ERROR LOG FOR AA401NYC                                            PAGE:     2
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
# 1000781610| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781611| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781612| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781613| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781614| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781615| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781616| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781617| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781618| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781619| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781620| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781621| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781622| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781623| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781624| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781625| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781626| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781627| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781628| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781629| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781630| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781631| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781632| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781633| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781634| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781635| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781636| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781637| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781638| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781639| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781640| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781641| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781642| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781643| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781644| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781645| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781646| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781647| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781648| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781649| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781650| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781651| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781652| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781653| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781654| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781655| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781656| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781657| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781658| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781659| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781660| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781661| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781662| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000781663| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 48820 not allowed with CONDO Abat
# 1000791206| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000791207| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000841002| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841003| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841004| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841005| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# Skipping record:
# 04-DEC-2023 08:59:36 PM                                ERROR LOG FOR AA401NYC                                            PAGE:     3
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
# 1000841006| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841007| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841008| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841009| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841010| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841011| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841012| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000841013| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 47660 not allowed with CONDO Abat
# 1000911109| 2020|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000911109| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |EXCODE 41856 not allowed with 421G
# 1000940001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000001-0000
#           |     |   |                               |2B)
# Skipping record: 1000940001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000006-0000
#           |     |   |                               |4H)
# Skipping record: 1000940001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000008-0000
#           |     |   |                               |2B)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000001-0000
#           |     |   |                               |2B)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000004-0000
#           |     |   |                               |5B)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000004-0000
#           |     |   |                               |12J)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000006-0000
#           |     |   |                               |4H)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000006-0000
#           |     |   |                               |4N)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000006-0000
#           |     |   |                               |6C)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000008-0000
#           |     |   |                               |2B)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000008-0000
#           |     |   |                               |22E)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 4-0 UNIT#: 24E. Unit
#           |     |   |                               |(100094000100000004-0000    24E)
# Skipping record: 1000940001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 8-0 UNIT#: 10B. Unit
#           |     |   |                               |(100094000100000008-0000    10B)
# Skipping record: 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000001-0000
#           |     |   |                               |2B)
# Skipping record: 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000004-0000
#           |     |   |                               |5B)
# Skipping record: 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000006-0000
#           |     |   |                               |4H)
# Skipping record: 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000006-0000
# Skipping record:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 04-DEC-2023 08:59:36 PM                                ERROR LOG FOR AA401NYC                                            PAGE:     4
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
#           |     |   |                               |4N)
# Skipping record: 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000007-0000
#           |     |   |                               |1D)
# Skipping record: 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 4-0 UNIT#: 24E. Unit
#           |     |   |                               |(100094000100000004-0000    24E)
# Skipping record: 1000940001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 8-0 UNIT#: 10B. Unit
#           |     |   |                               |(100094000100000008-0000    10B)
# Skipping record: 1000940001| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000007-0000
#           |     |   |                               |1D)
# Skipping record: 1000940001| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000008-0000
#           |     |   |                               |22E)
# Skipping record: 1000940001| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 4-0 UNIT#: 24E. Unit
#           |     |   |                               |(100094000100000004-0000    24E)
# Skipping record: 1000940001| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 8-0 UNIT#: 10B. Unit
#           |     |   |                               |(100094000100000008-0000    10B)
# Skipping record: 1000940001| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1000940001| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100094000100000007-0000
#           |     |   |                               |1D)
# Skipping record: 1001060002| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001061136| 2019|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.
# 1001170001| 2019|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000001-0000
#           |     |   |                               |14A)
# Skipping record: 1001170001| 2019|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000002-0000
#           |     |   |                               |7D)
# Skipping record: 1001170001| 2019|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000002-0000
#           |     |   |                               |12D)
# Skipping record: 1001170001| 2019|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000002-0000
#           |     |   |                               |13D)
# Skipping record: 1001170001| 2019|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000002-0000
#           |     |   |                               |21D)
# Skipping record: 1001170001| 2019|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000003-0000
#           |     |   |                               |16B)
# Skipping record: 1001170001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 18B. Unit
#           |     |   |                               |(100117000100000001-0000    18B)
# Skipping record: 1001170001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |STAR exmp is not allowed due to income for BLDG#: 2-0 UNIT#: 16G. Unit
#           |     |   |                               |(100117000100000002-0000    16G)
# Skipping record: 1001170001| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000001-0000
#           |     |   |                               |14A)
# Skipping record: 1001170001| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000002-0000
#           |     |   |                               |7D)
# Skipping record: 1001170001| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Income must be entered for STAR exemption.. Unit (100117000100000003-0000
# Skipping record:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 04-DEC-2023 08:59:36 PM                                ERROR LOG FOR AA401NYC                                            PAGE:     5
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
#           |     |   |                               |16B)
# Skipping record: 1001170001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100117000100000003-0000
#           |     |   |                               |16H)
# Skipping record: 1001170001| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 1-0 UNIT#: 5A. Unit
#           |     |   |                               |(100117000100000001-0000     5A)
# Skipping record: 1001170001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100117000100000003-0000
#           |     |   |                               |16H)
# Skipping record: 1001170001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 1-0 UNIT#: 5A. Unit
#           |     |   |                               |(100117000100000001-0000     5A)
# Skipping record: 1001170001| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 2-0 UNIT#: 15E. Unit
#           |     |   |                               |(100117000100000002-0000    15E)
# Skipping record: 1001170001| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age . Unit (100117000100000003-0000
#           |     |   |                               |16H)
# Skipping record: 1001170001| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 1-0 UNIT#: 5A. Unit
#           |     |   |                               |(100117000100000001-0000     5A)
# Skipping record: 1001321084| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001351002| 2021|65 |CALCXMPNY.CALCPAR_NYC          |STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 8E. Unit
#           |     |   |                               |(100135100200000001-0000     8E)
# Skipping record: 1001401144| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001440023| 2015|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large. Unit
#           |     |   |                               |(100144002300000001-0000     04). Unit (100144002300000001-0000     04)
# Skipping record: 1001440023| 2016|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001440023| 2017|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2017|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001440023| 2018|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2018|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001440023| 2019|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2019|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001440023| 2020|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2020|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001440023| 2021|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2021|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001440023| 2022|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2022|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001440023| 2023|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2023|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# Skipping record:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 04-DEC-2023 08:59:36 PM                                ERROR LOG FOR AA401NYC                                            PAGE:     6
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
# 1001440023| 2024|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/41565934
# Skipping record: 1001440023| 2024|65 |Exval Trigger.                 |ORA-06502: PL/SQL: numeric or value error: number precision too large
# 1001451319| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001461102| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 1-0 UNIT#: 3N. Unit
#           |     |   |                               |(100146110200000001-0000     3N)
# Skipping record: 1001461102| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 1-0 UNIT#: 3N. Unit
#           |     |   |                               |(100146110200000001-0000     3N)
# Skipping record: 1001471618| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001610001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exmp is not allowed due to age for BLDG#: 1-0 UNIT#: 18E. Unit
#           |     |   |                               |(100161000100000001-0000    18E)
# Skipping record: 1001721148| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1001721211| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1001731029| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001751102| 2024|65 |CALCXMPNY.WRITE_EXDET          |Error - ORA-00001: unique constraint (IAS.EXDET_ - Excode/Lineno/Caseno:
#           |     |   |                               |41856/1/38381397
# Skipping record: 1001791330| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001871002| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1001881115| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1001931602| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1002021058| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1002021058| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1002021089| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1002021089| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1002021123| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1002021123| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1002021123| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 1002171016| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 1002251002| 2021|65 |CALCXMPNY.CALCPAR_NYC          |STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 4N. Unit
# ...
# 5063150071| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5063240009| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5063590007| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5063590007| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5063590007| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5063660034| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5063660034| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5064230016| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5064240018| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5064550028| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# Skipping record:
# 04-DEC-2023 08:59:36 PM                                ERROR LOG FOR AA401NYC                                            PAGE:   235
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
# 5064750250| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5064990116| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5066660040| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067230115| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067250038| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067250038| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067250038| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067270032| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067270032| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067270120| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067270120| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5067650094| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5067890006| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5068450136| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068450136| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068460048| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068460048| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068610101| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068610101| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068610101| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068690052| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068690052| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068690052| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068790028| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5068820019| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068820019| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068870033| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068870033| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068880016| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5068880016| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5069070035| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5069070035| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5069250035| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5069460115| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5069480022| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5069660063| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5069700053| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5069700053| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5069730009| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5069980001| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5070381018| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5070381040| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5070401017| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070411101| 2021|65 |CALCXMPNY.CALCPAR_NYC          |STAR exmp is not allowed due to age for BLDG#: 1-0 UNIT#: 209
# 5070411101| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Cannot add personal exemptions to COOP parcels. Add it to coop units in unit
#           |     |   |                               |transaction.
# Skipping record: 5070740003| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070740003| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070810030| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070820140| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070850088| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070860044| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070870011| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070870011| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070910139| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070910139| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070910139| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5070930019| 2022|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Excode 41121 or 41131 required for Disabled Vet exemption.
# 5070930019| 2023|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Excode 41121 or 41131 required for Disabled Vet exemption.
# Skipping record:
#
# 04-DEC-2023 08:59:36 PM                                ERROR LOG FOR AA401NYC                                            PAGE:   236
# Skipping record: PARID     |TAXYR|JUR|PROCEDURE                      |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
# 5073170023| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5073490008| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5073490008| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5073510002| 2022|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5074990013| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5074990013| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5075340388| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5075780212| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5075780212| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5075960204| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5075960221| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078120017| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078120017| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078380085| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5078500053| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078500053| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078530050| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078530050| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078530050| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078601029| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC  |Cannot add personal exemptions to COOP parcels. Add it to coop units in unit
#           |     |   |                               |transaction.
# Skipping record: 5078630011| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078630011| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078630011| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078640067| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078640067| 2025|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078880083| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078880083| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5078910039| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5079150036| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5079150036| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5079160045| 2021|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5079260067| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5079400016| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5079450035| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5079450035| 2024|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# 5080220008| 2021|65 |CALCXMPNY.CALCPAR_NYC          |NYAPP_STAR exemption is not allowed due to income
# 5080340100| 2023|65 |CALCXMPNY.CALCPAR_NYC          |+ SENIOR exemption is not allowed due to age
# Skipping record:
#
#
# Empty DataFrame
# Columns: [PARID, TAXYR, JUR, PROCEDURE, ERRMSG]
# Index: []

# %%
# import pandas as pd

# # Paste the data for the first page here
# page_1_data = """
# 04-DEC-2023 08:59:36 PM ERROR LOG FOR AA401NYC PAGE: 1
# PARID |TAXYR|JUR|PROCEDURE |ERRMSG
# ----------|-----|---|-------------------------------|------------------------------------------------------------------------------
# 1000110014| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC |Income must be entered for STAR exemption.. Unit (100011001400000001-00004)
# | | | |4)
# 1000110014| 2021|65 |IASW_EXAPP_VAL.VAL_EXCODE_NYC |Income must be entered for STAR exemption.. Unit (100011001400000001-00007)
# | | | |7)
# """

# # Split the data into lines
# lines = page_1_data.split('\n')

# # Extract header and data
# header = lines[4]
# data_lines = lines[6:-1]  # Exclude header and last empty line

# # Define the columns with leading/trailing spaces removed
# columns = [col.strip() for col in header.split('|')]

# # Create a list to store dictionaries
# data_list = []

# # Process each line and append to the list
# for line in data_lines:
#     # Split the line based on the pipe (|) separator
#     values = [value.strip() for value in line.split('|')]
    
#     # Filter out undesired lines
#     if values[4] and values[4] not in ('4)', '7)'):
#         # Skip lines with empty values
#         if not all(value == '' for value in values):
#             data_dict = {col: val for col, val in zip(columns, values)}
#             data_list.append(data_dict)

# # Create a DataFrame from the list of dictionaries
# df_page_1 = pd.DataFrame(data_list)

# # Display the entire DataFrame without truncation
# pd.set_option("display.max_colwidth", None)
# print(df_page_1)
# Out:
#    1000110014  2021  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC  \
# 0  1000110014  2021  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
#
#    Income must be entered for STAR exemption.. Unit (100011001400000001-00004)
# 0  Income must be entered for STAR exemption.. Unit (100011001400000001-00007)

# %%
# # Export DataFrame to a CSV file with an absolute path
# df_page_1.to_csv('C:\\Users\\fatogunt\\Downloads\\output.csv', index=False)

# # Or print individual columns separately
# for index, row in df_page_1.iterrows():
#     print(f"PARID: {row['1000110014']}")
#     print(f"TAXYR: {row['2021']}")
#     print(f"JUR: {row['65']}")
#     print(f"PROCEDURE: {row['IASW_EXAPP_VAL.VAL_EXCODE_NYC']}")
#     print(f"ERRMSG: {row['Income must be entered for STAR exemption.. Unit (100011001400000001-00004)']}\n{'-'*80}")
# Out:
# PARID: 1000110014
# TAXYR: 2021
# JUR: 65
# PROCEDURE: IASW_EXAPP_VAL.VAL_EXCODE_NYC
# ERRMSG: Income must be entered for STAR exemption.. Unit (100011001400000001-00007)
# --------------------------------------------------------------------------------

# %%
import pandas as pd
import pdfplumber

# Load the PDF file
pdf_file_path = 'C:\\Users\\fatogunt\\Downloads\\AA731NYC_ASMT.pdf'
with pdfplumber.open(pdf_file_path) as pdf:
    # Extract text from the first page
    page_1_text = pdf.pages[0].extract_text()

# Split the text into lines
lines = page_1_text.split('\n')

# Extract header and data
header = lines[4]
data_lines = lines[6:-1]  # Exclude header and last empty line

# Create a list to store dictionaries
data_list = []

# Process each line and append to the list
for line in data_lines:
    # Split the line based on the pipe (|) separator
    values = [value.strip() for value in line.split('|')]
    
    # Filter out undesired lines
    if values[4] and values[4] not in ('4)', '7)'):
        data_dict = {col: val for col, val in zip(columns, values)}
        data_list.append(data_dict)

# Create a DataFrame from the list of dictionaries
df_page_1 = pd.DataFrame(data_list)

# Display the DataFrame
print(df_page_1)
# Out:
#     1000110014  2021  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC  \
# 0   1000161437  2016  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 1   1000161547  2015  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 2   1000161555  2016  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 3   1000161594  2015  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 4   1000161595  2015  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 5   1000161596  2021  65          CALCXMPNY.CALCPAR_NYC
# 6   1000162292  2023  65          Asmt before row Trig.
# 7   1000165012  2023  65          CALCXMPNY.CALCPAR_NYC
# 8   1000165012  2024  65          CALCXMPNY.CALCPAR_NYC
# 9   1000165678  2024  65          CALCXMPNY.CALCPAR_NYC
# 10  1000165678  2025  65          CALCXMPNY.CALCPAR_NYC
# 11  1000165707  2021  65          CALCXMPNY.CALCPAR_NYC
# 12  1000166044  2021  65          CALCXMPNY.CALCPAR_NYC
# 13  1000166044  2022  65          CALCXMPNY.CALCPAR_NYC
# 14  1000166128  2021  65          CALCXMPNY.CALCPAR_NYC
# 15  1000166128  2022  65          CALCXMPNY.CALCPAR_NYC
# 16  1000168058  2021  65          CALCXMPNY.CALCPAR_NYC
# 17  1000168058  2022  65          CALCXMPNY.CALCPAR_NYC
# 18  1000168147  2021  65          CALCXMPNY.CALCPAR_NYC
# 19  1000168147  2022  65          CALCXMPNY.CALCPAR_NYC
# 20  1000181009  2021  65          CALCXMPNY.CALCPAR_NYC
# 21  1000181088  2021  65          CALCXMPNY.CALCPAR_NYC
# 22  1000411210  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 23  1000411212  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 24  1000411218  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 25  1000411235  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 26  1000411237  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 27  1000411245  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 28  1000411247  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 29  1000411259  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 30  1000411263  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 31  1000411269  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 32  1000411277  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 33  1000411278  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 34  1000411288  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 35  1000531023  2021  65          CALCXMPNY.CALCPAR_NYC
# 36  1000640008  2021  65          CALCXMPNY.CALCPAR_NYC
# 37
# 38  1000651001  2021  65          CALCXMPNY.CALCPAR_NYC
# 39
# 40  1000761156  2021  65          CALCXMPNY.CALCPAR_NYC
# 41  1000761331  2021  65          CALCXMPNY.CALCPAR_NYC
# 42  1000761424  2021  65          CALCXMPNY.CALCPAR_NYC
# 43  1000781601  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 44  1000781602  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 45  1000781603  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 46  1000781604  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 47  1000781605  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 48  1000781606  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 49  1000781607  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 50  1000781608  2020  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC
#
#    Income must be entered for STAR exemption.. Unit (100011001400000001-00004)
# 0                                   Income must be entered for STAR exemption.
# 1                                   Income must be entered for STAR exemption.
# 2                                   Income must be entered for STAR exemption.
# 3                                   Income must be entered for STAR exemption.
# 4                                   Income must be entered for STAR exemption.
# 5                            NYAPP_STAR exemption is not allowed due to income
# 6                           ORA-00001: unique constraint (IAS.ASMT_H) violated
# 7                                 + SENIOR exemption is not allowed due to age
# 8                                 + SENIOR exemption is not allowed due to age
# 9                                 + SENIOR exemption is not allowed due to age
# 10                                + SENIOR exemption is not allowed due to age
# 11                           NYAPP_STAR exemption is not allowed due to income
# 12                           NYAPP_STAR exemption is not allowed due to income
# 13                           NYAPP_STAR exemption is not allowed due to income
# 14                           NYAPP_STAR exemption is not allowed due to income
# 15                           NYAPP_STAR exemption is not allowed due to income
# 16                           NYAPP_STAR exemption is not allowed due to income
# 17                           NYAPP_STAR exemption is not allowed due to income
# 18                           NYAPP_STAR exemption is not allowed due to income
# 19                           NYAPP_STAR exemption is not allowed due to income
# 20                           NYAPP_STAR exemption is not allowed due to income
# 21                           NYAPP_STAR exemption is not allowed due to income
# 22                                          EXCODE 41856 not allowed with 421G
# 23                                          EXCODE 41856 not allowed with 421G
# 24                                          EXCODE 41856 not allowed with 421G
# 25                                          EXCODE 41856 not allowed with 421G
# 26                                          EXCODE 41856 not allowed with 421G
# 27                                          EXCODE 41856 not allowed with 421G
# 28                                          EXCODE 41836 not allowed with 421G
# 29                                          EXCODE 41856 not allowed with 421G
# 30                                          EXCODE 41856 not allowed with 421G
# 31                                          EXCODE 41856 not allowed with 421G
# 32                                          EXCODE 41856 not allowed with 421G
# 33                                          EXCODE 41856 not allowed with 421G
# 34                                          EXCODE 41856 not allowed with 421G
# 35                           NYAPP_STAR exemption is not allowed due to income
# 36      STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 13B. Unit
# 37                                               (100064000800000001-0000 13B)
# 38       STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 4B. Unit
# 39                                                (100065100100000001-0000 4B)
# 40                           NYAPP_STAR exemption is not allowed due to income
# 41                           NYAPP_STAR exemption is not allowed due to income
# 42                           NYAPP_STAR exemption is not allowed due to income
# 43                                    EXCODE 48820 not allowed with CONDO Abat
# 44                                    EXCODE 48820 not allowed with CONDO Abat
# 45                                    EXCODE 48820 not allowed with CONDO Abat
# 46                                    EXCODE 48820 not allowed with CONDO Abat
# 47                                    EXCODE 48820 not allowed with CONDO Abat
# 48                                    EXCODE 48820 not allowed with CONDO Abat
# 49                                    EXCODE 48820 not allowed with CONDO Abat
# 50                                    EXCODE 48820 not allowed with CONDO Abat

# %%
import pandas as pd
import pdfplumber

# Load the PDF file
pdf_file_path = 'C:\\Users\\fatogunt\\Downloads\\AA731NYC_ASMT.pdf'
with pdfplumber.open(pdf_file_path) as pdf:
    # Extract text from the first page
    page_1_text = pdf.pages[0].extract_text()

# Split the text into lines
lines = page_1_text.split('\n')

# Find the line that contains the pipe character (|) and use it as the header
header_line = next(line for line in lines if '|' in line)
header = header_line.strip()

# Extract data lines
data_lines = lines[lines.index(header_line) + 1 : -1]  # Exclude header and last empty line

# Create a list to store dictionaries
data_list = []

# Define columns based on the header line
columns = [col.strip() for col in header.split('|')]

# Process each line and append to the list
for line in data_lines:
    # Split the line based on the pipe (|) separator
    values = [value.strip() for value in line.split('|')]
    
    # Filter out undesired lines
    if values[4] and values[4] not in ('4)', '7)'):
        data_dict = {col: val for col, val in zip(columns, values)}
        data_list.append(data_dict)

# Create a DataFrame from the list of dictionaries
df_page_1 = pd.DataFrame(data_list)

# Display the DataFrame
print(df_page_1)
# Out:
#          PARID  TAXYR  JUR                        PROCEDURE  \
# 0   ----------  -----  ---  -------------------------------
# 1   1000110014   2021   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 2   1000110014   2021   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 3   1000161437   2016   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 4   1000161547   2015   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 5   1000161555   2016   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 6   1000161594   2015   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 7   1000161595   2015   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 8   1000161596   2021   65            CALCXMPNY.CALCPAR_NYC
# 9   1000162292   2023   65            Asmt before row Trig.
# 10  1000165012   2023   65            CALCXMPNY.CALCPAR_NYC
# 11  1000165012   2024   65            CALCXMPNY.CALCPAR_NYC
# 12  1000165678   2024   65            CALCXMPNY.CALCPAR_NYC
# 13  1000165678   2025   65            CALCXMPNY.CALCPAR_NYC
# 14  1000165707   2021   65            CALCXMPNY.CALCPAR_NYC
# 15  1000166044   2021   65            CALCXMPNY.CALCPAR_NYC
# 16  1000166044   2022   65            CALCXMPNY.CALCPAR_NYC
# 17  1000166128   2021   65            CALCXMPNY.CALCPAR_NYC
# 18  1000166128   2022   65            CALCXMPNY.CALCPAR_NYC
# 19  1000168058   2021   65            CALCXMPNY.CALCPAR_NYC
# 20  1000168058   2022   65            CALCXMPNY.CALCPAR_NYC
# 21  1000168147   2021   65            CALCXMPNY.CALCPAR_NYC
# 22  1000168147   2022   65            CALCXMPNY.CALCPAR_NYC
# 23  1000181009   2021   65            CALCXMPNY.CALCPAR_NYC
# 24  1000181088   2021   65            CALCXMPNY.CALCPAR_NYC
# 25  1000411210   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 26  1000411212   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 27  1000411218   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 28  1000411235   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 29  1000411237   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 30  1000411245   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 31  1000411247   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 32  1000411259   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 33  1000411263   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 34  1000411269   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 35  1000411277   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 36  1000411278   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 37  1000411288   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 38  1000531023   2021   65            CALCXMPNY.CALCPAR_NYC
# 39  1000640008   2021   65            CALCXMPNY.CALCPAR_NYC
# 40
# 41  1000651001   2021   65            CALCXMPNY.CALCPAR_NYC
# 42
# 43  1000761156   2021   65            CALCXMPNY.CALCPAR_NYC
# 44  1000761331   2021   65            CALCXMPNY.CALCPAR_NYC
# 45  1000761424   2021   65            CALCXMPNY.CALCPAR_NYC
# 46  1000781601   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 47  1000781602   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 48  1000781603   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 49  1000781604   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 50  1000781605   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 51  1000781606   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 52  1000781607   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
# 53  1000781608   2020   65    IASW_EXAPP_VAL.VAL_EXCODE_NYC
#
#                                                                             ERRMSG
# 0   ------------------------------------------------------------------------------
# 1        Income must be entered for STAR exemption.. Unit (100011001400000001-0000
# 2        Income must be entered for STAR exemption.. Unit (100011001400000001-0000
# 3                                       Income must be entered for STAR exemption.
# 4                                       Income must be entered for STAR exemption.
# 5                                       Income must be entered for STAR exemption.
# 6                                       Income must be entered for STAR exemption.
# 7                                       Income must be entered for STAR exemption.
# 8                                NYAPP_STAR exemption is not allowed due to income
# 9                               ORA-00001: unique constraint (IAS.ASMT_H) violated
# 10                                    + SENIOR exemption is not allowed due to age
# 11                                    + SENIOR exemption is not allowed due to age
# 12                                    + SENIOR exemption is not allowed due to age
# 13                                    + SENIOR exemption is not allowed due to age
# 14                               NYAPP_STAR exemption is not allowed due to income
# 15                               NYAPP_STAR exemption is not allowed due to income
# 16                               NYAPP_STAR exemption is not allowed due to income
# 17                               NYAPP_STAR exemption is not allowed due to income
# 18                               NYAPP_STAR exemption is not allowed due to income
# 19                               NYAPP_STAR exemption is not allowed due to income
# 20                               NYAPP_STAR exemption is not allowed due to income
# 21                               NYAPP_STAR exemption is not allowed due to income
# 22                               NYAPP_STAR exemption is not allowed due to income
# 23                               NYAPP_STAR exemption is not allowed due to income
# 24                               NYAPP_STAR exemption is not allowed due to income
# 25                                              EXCODE 41856 not allowed with 421G
# 26                                              EXCODE 41856 not allowed with 421G
# 27                                              EXCODE 41856 not allowed with 421G
# 28                                              EXCODE 41856 not allowed with 421G
# 29                                              EXCODE 41856 not allowed with 421G
# 30                                              EXCODE 41856 not allowed with 421G
# 31                                              EXCODE 41836 not allowed with 421G
# 32                                              EXCODE 41856 not allowed with 421G
# 33                                              EXCODE 41856 not allowed with 421G
# 34                                              EXCODE 41856 not allowed with 421G
# 35                                              EXCODE 41856 not allowed with 421G
# 36                                              EXCODE 41856 not allowed with 421G
# 37                                              EXCODE 41856 not allowed with 421G
# 38                               NYAPP_STAR exemption is not allowed due to income
# 39          STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 13B. Unit
# 40                                                   (100064000800000001-0000 13B)
# 41           STAR exmp is not allowed due to income for BLDG#: 1-0 UNIT#: 4B. Unit
# 42                                                    (100065100100000001-0000 4B)
# 43                               NYAPP_STAR exemption is not allowed due to income
# 44                               NYAPP_STAR exemption is not allowed due to income
# 45                               NYAPP_STAR exemption is not allowed due to income
# 46                                        EXCODE 48820 not allowed with CONDO Abat
# 47                                        EXCODE 48820 not allowed with CONDO Abat
# 48                                        EXCODE 48820 not allowed with CONDO Abat
# 49                                        EXCODE 48820 not allowed with CONDO Abat
# 50                                        EXCODE 48820 not allowed with CONDO Abat
# 51                                        EXCODE 48820 not allowed with CONDO Abat
# 52                                        EXCODE 48820 not allowed with CONDO Abat
# 53                                        EXCODE 48820 not allowed with CONDO Abat

# %%
# import pandas as pd
# import pdfplumber
# import re

# # Function to extract text from PDF using pdfplumber
# def extract_text(pdf_path):
#     with pdfplumber.open(pdf_path) as pdf:
#         text = ''
#         for page in pdf.pages:
#             text += page.extract_text()
#         return text

# # Import PDF
# text = extract_text('C:\\Users\\fatogunt\\Downloads\\AA731NYC_ASMT.pdf')

# # Define a regular expression pattern to capture records
# pattern = re.compile(r'(\d+)\s*\|\s*(\d+)\s*\|\s*(\d+)\s*\|\s*(.+?)\s*\|\s*(.+?)\s*')

# # Find all matches in the text
# matches = pattern.findall(text)

# # Debug prints
# for match in matches:
#     print("Match:", match)

# # Process matches
# parids, taxyrs, jurs, procedures, errmsgs = zip(*matches)

# # Create the DataFrame
# df = pd.DataFrame({
#     'PARID': parids,
#     'TAXYR': taxyrs,
#     'JUR': jurs,
#     'PROCEDURE': procedures,
#     'ERRMSG': errmsgs
# })

# # Print the first few rows of the DataFrame
# print(df.head())

# # Save DataFrame to CSV
# df.to_csv('error_log.csv', index=False)
# Out:
# Match: ('1000110014', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1000110014', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1000161437', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1000161547', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1000161555', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1000161594', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1000161595', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1000161596', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000162292', '2023', '65', 'Asmt before row Trig.', 'O')
# Match: ('1000165012', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000165012', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000165678', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000165678', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000165707', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000166044', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000166044', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000166128', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000166128', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000168058', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000168058', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000168147', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000168147', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000181009', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000181088', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000411210', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411212', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411218', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411235', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411237', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411245', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411247', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411259', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411263', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411269', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411277', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411278', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000411288', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000531023', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000640008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1000651001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1000761156', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000761331', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000761424', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1000781601', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781602', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781603', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781604', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781605', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781606', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781607', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781608', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781609', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781610', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781611', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781612', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781613', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781614', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781615', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781616', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781617', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781618', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781619', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781620', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781621', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781622', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781623', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781624', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781625', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781626', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781627', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781628', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781629', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781630', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781631', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781632', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781633', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781634', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781635', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781636', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781637', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781638', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781639', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781640', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781641', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781642', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781643', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781644', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781645', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781646', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781647', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781648', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781649', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781650', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781651', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781652', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781653', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781654', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781655', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781656', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781657', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781658', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781659', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781660', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781661', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781662', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000781663', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000791206', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000791207', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841002', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841003', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841004', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841005', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841006', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841007', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841008', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841009', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841010', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841011', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841012', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000841013', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000911109', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000911109', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1000940001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1000940001', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001060002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001061136', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1001170001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1001170001', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1001170001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001170001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001170001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001170001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001170001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001170001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001170001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001321084', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001351002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1001401144', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001440023', '2015', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2016', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2017', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2017', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2018', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2018', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2019', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2019', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2020', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2020', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2021', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2022', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2023', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2023', '65', 'Exval Trigger.', 'O')
# Match: ('1001440023', '2024', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001440023', '2024', '65', 'Exval Trigger.', 'O')
# Match: ('1001451319', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001461102', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001461102', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001471618', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001610001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001721148', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001721211', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001731029', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001751102', '2024', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1001791330', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001871002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1001881115', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1001931602', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1002021058', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002021058', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002021089', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002021089', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002021123', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002021123', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002021123', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002171016', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1002251002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1002461011', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002630008', '2017', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1002630008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1002630008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1002630008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1002630008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1002630008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1002630008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1002630008', '2022', '65', 'Exval Trigger.', 'O')
# Match: ('1002741025', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002741181', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002741181', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002760027', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002761201', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1002831112', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002831112', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002971132', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1002971132', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003110013', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003110013', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003110013', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003110013', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003110013', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003110013', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003110013', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003150001', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003150001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003150001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003210001', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003210001', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003210001', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003210001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003210001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003210001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003210001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003210001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003210001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003210001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003210001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003210001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003210001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003310065', '2010', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003310065', '2010', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003310065', '2010', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003310065', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003310065', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003310120', '2010', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1003310120', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003440152', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003451027', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1003480007', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003480007', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003491044', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003491044', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003491044', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003841002', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003841002', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1003890017', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1003941101', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941102', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941103', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941104', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941105', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941106', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941107', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941108', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941109', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941110', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941111', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941112', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941201', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941202', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941203', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941204', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941205', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941206', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941207', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941208', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941209', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941210', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941211', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1003941212', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051101', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051102', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051102', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051102', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051103', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051103', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051103', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051104', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051104', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051104', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051105', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051105', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051105', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051106', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051106', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051106', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051107', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051107', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051107', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051108', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051108', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051108', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051109', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051109', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051109', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051110', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051110', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004051110', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1004160055', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1004190045', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1004211109', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1004310025', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1004310031', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1004381105', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1004411030', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1004411030', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1004430030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1004461102', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1004461102', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1004540066', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1004660048', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1004691102', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1004701006', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1004701006', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1004730042', '2023', '65', 'COOPMAST Trigger.', 'O')
# Match: ('1004750007', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1004820013', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1004861004', '2020', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1004861004', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1004980015', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1004990022', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005040014', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005040014', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005040014', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005060027', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005060027', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005150001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005171004', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005190014', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005190014', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005190018', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005220004', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005220004', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005220004', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005251643', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1005260022', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005260022', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005280008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005280008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005291211', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1005311055', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1005320020', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005320020', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005371002', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005371002', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005371002', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005371002', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005371002', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005371002', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005421002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005480028', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005481003', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005481003', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005521003', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1005521009', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1005521009', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1005521009', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1005550001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005550001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005550028', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1005550028', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1005550028', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1005560044', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005601103', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005601103', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005610014', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005611003', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005620036', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005630037', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005630037', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005660001', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1005660001', '2017', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005660001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005660001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005660018', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005670019', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005670019', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005670031', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005670031', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005670031', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005680024', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005711406', '2020', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1005711406', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1005740058', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005740058', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005740059', '2024', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005750072', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005760001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005760049', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1005760049', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005761560', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1005761578', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1005761601', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1005761601', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1005761702', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005770030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005770030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005840061', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005840061', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005841002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005841002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005900077', '2023', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1005910026', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005920066', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005920066', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1005941212', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1005950006', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006011022', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1006041041', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1006080039', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006080074', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006100048', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1006100048', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1006121022', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1006161002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006200053', '2024', '65', 'Exval Trigger.', 'O')
# Match: ('1006210035', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1006210035', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1006210035', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1006210035', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1006231002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006240001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006241302', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006301105', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1006301105', '2022', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1006320006', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1006340023', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1006340023', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1006351004', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1006381110', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1006420045', '2024', '65', 'Exval Trigger.', 'O')
# Match: ('1006951717', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007170009', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007200075', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007211062', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007211062', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007211062', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007211062', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007221067', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007380023', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007400043', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1007400046', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007400047', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007400047', '2024', '65', 'Exval Trigger.', 'O')
# Match: ('1007420022', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007421045', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007451104', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007451104', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007451104', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007451104', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007451104', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007461122', '2020', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1007461139', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007480001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007480001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007480001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007490001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007490001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'C')
# Match: ('1007510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007510001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1007520001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007520001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007520001', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1007600007', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007620014', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007621113', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007639008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007650062', '2023', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1007650070', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007660039', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007661129', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007661173', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007681132', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007681190', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007690031', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007710038', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007710038', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007710038', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007710038', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1007730012', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007741015', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007741044', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007741117', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007750060', '2023', '65', 'COOPMAST Trigger.', 'O')
# Match: ('1007781046', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007900001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007900001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007921030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007921102', '2024', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1007921302', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007931205', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007951029', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007960001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007960013', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1007961323', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007981214', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1007990057', '2024', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1007991013', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008160031', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', '+')
# Match: ('1008160031', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', '+')
# Match: ('1008160031', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', '+')
# Match: ('1008160031', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', '+')
# Match: ('1008160031', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', '+')
# Match: ('1008160031', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008160062', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008160062', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008160062', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008160062', '2023', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008161095', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008170029', '2020', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008170029', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008171029', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008201103', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008221208', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008270042', '2024', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008270060', '2024', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008300074', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008370040', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008420007', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008440011', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008440011', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008440011', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008440011', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008491295', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008491670', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008491670', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008501301', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008510013', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008580032', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008621478', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008640035', '2018', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1008641002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008641002', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008660064', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008670033', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008670033', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008670046', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008670057', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008681331', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008701338', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008710030', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008710044', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008710044', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008710044', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008710044', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008730019', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008750008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008750019', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008750047', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008770030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008770042', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008770042', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008770042', '2015', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008770042', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008770042', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008851304', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008890015', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1008900054', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008900054', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008901026', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008901049', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008901142', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008901249', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008901268', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008901310', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008910003', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008910003', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008910023', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008910077', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008920020', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008920025', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008930020', '2019', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1008930020', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008930020', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008930034', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008930041', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008940403', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1008941403', '2023', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1008950029', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008950029', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008950029', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008950029', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008950029', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1008960039', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008970001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008980001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008990001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008990001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008990008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1008990022', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008990022', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1008990022', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009020001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009020001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009031032', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009031127', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009031127', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009040050', '2017', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009050026', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009050035', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1009050035', '2021', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1009050035', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1009050035', '2022', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1009050035', '2023', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1009050035', '2023', '65', 'CALCXMPNY.WRITE_EXDET', 'E')
# Match: ('1009060001', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009060001', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009060024', '2012', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009060024', '2013', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009060024', '2014', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009060024', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009060024', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009070056', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009090001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009090001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009090001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009130028', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009160061', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1009170017', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009170017', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009170017', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009170017', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009170017', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009170017', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009210019', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009280001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009281107', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009281239', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009300001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009300001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009300001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009300001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009351095', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009361019', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009361206', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009362031', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009362076', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009363143', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009363261', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009364258', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009401118', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009430001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009430001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('1009431174', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009431649', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009441096', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'N')
# Match: ('1009451003', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009451003', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009681069', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1009681310', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1009691382', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1010081046', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('1010081180', '2016', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'I')
# Match: ('1010091001', '2020', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1010091001', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('1010181117', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1010181117', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('1010251002', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# ...
# Match: ('5050940011', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5050940011', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5051000043', '2023', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('5051080039', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5051100035', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5051100035', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5051370001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5051400068', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052090028', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5052420019', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052440018', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052480007', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052480007', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052540028', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052540028', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052680087', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5052680188', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052680192', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052680192', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052720030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('5052980042', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052980042', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052990058', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5052990058', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053070026', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053190074', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053190074', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053220086', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053220086', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053220086', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053240167', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053240167', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053350001', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053350001', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053630083', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053630083', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053630083', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053850045', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5053950023', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5053970030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5054020038', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054020038', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054020038', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054391058', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054391058', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054420115', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5054450053', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054500080', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054550073', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054550073', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054600124', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054601002', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'C')
# Match: ('5054610052', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054610052', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054640112', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054640112', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054640112', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054750022', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054820068', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054850034', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054890098', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054940185', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5054940185', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5055350039', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5055900109', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5055920042', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5056050101', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056050101', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056120097', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056120097', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056120192', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056120192', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056120192', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056160134', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056260069', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056430094', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056510132', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056640026', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056640026', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056640058', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056680155', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056680155', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056730030', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056740103', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056740103', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056800171', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056830113', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5056870184', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057050021', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057050021', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057050030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5057240120', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057240129', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057260087', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057260087', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057430204', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5057760012', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060160001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5060171028', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060171028', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060171028', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060171121', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5060190006', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060190006', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060200069', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060200069', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060210294', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060210294', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060270008', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060270008', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060270008', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060290049', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060290049', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060430065', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060430065', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060480011', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060480011', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060480020', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060550077', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5060870141', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5061090060', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062050100', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062050100', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062110024', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062140003', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062140003', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062210032', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062450249', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062510041', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062660033', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5062660033', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5063150071', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5063240009', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5063590007', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5063590007', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5063590007', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5063660034', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5063660034', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5064230016', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5064240018', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5064550028', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5064750250', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5064990116', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5066660040', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067230115', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067250038', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067250038', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067250038', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067270032', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067270032', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067270120', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067270120', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5067650094', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5067890006', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5068450136', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068450136', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068460048', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068460048', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068610101', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068610101', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068610101', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068690052', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068690052', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068690052', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068790028', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5068820019', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068820019', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068870033', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068870033', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068880016', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5068880016', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5069070035', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5069070035', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5069250035', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5069460115', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5069480022', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5069660063', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5069700053', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5069700053', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5069730009', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5069980001', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5070381018', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5070381040', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5070401017', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070411101', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'S')
# Match: ('5070411101', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'C')
# Match: ('5070740003', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070740003', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070810030', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070820140', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070850088', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070860044', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070870011', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070870011', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070910139', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070910139', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070910139', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5070930019', '2022', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('5070930019', '2023', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'E')
# Match: ('5073170023', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5073490008', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5073490008', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5073510002', '2022', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5074990013', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5074990013', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5075340388', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5075780212', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5075780212', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5075960204', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5075960221', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078120017', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078120017', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078380085', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5078500053', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078500053', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078530050', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078530050', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078530050', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078601029', '2021', '65', 'IASW_EXAPP_VAL.VAL_EXCODE_NYC', 'C')
# Match: ('5078630011', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078630011', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078630011', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078640067', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078640067', '2025', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078880083', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078880083', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5078910039', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5079150036', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5079150036', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5079160045', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5079260067', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5079400016', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5079450035', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5079450035', '2024', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
# Match: ('5080220008', '2021', '65', 'CALCXMPNY.CALCPAR_NYC', 'N')
# Match: ('5080340100', '2023', '65', 'CALCXMPNY.CALCPAR_NYC', '+')
#         PARID TAXYR JUR                      PROCEDURE ERRMSG
# 0  1000110014  2021  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 1  1000110014  2021  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 2  1000161437  2016  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 3  1000161547  2015  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 4  1000161555  2016  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I

# %%
# import pandas as pd
# import pdfplumber
# import re

# # Function to extract text from PDF using pdfplumber
# def extract_text(pdf_path):
#     with pdfplumber.open(pdf_path) as pdf:
#         text = ''
#         for page in pdf.pages:
#             text += page.extract_text()
#         return text

# # Import PDF
# text = extract_text('C:\\Users\\fatogunt\\Downloads\\AA731NYC_ASMT.pdf')

# # Define a regular expression pattern to capture records
# pattern = re.compile(r'(\d+)\s*\|\s*(\d+)\s*\|\s*(\d+)\s*\|\s*(.+?)\s*\|\s*(.+?)\s*')

# # Find all matches in the text
# matches = pattern.findall(text)

# # Create the DataFrame directly from matches
# df = pd.DataFrame(matches, columns=['PARID', 'TAXYR', 'JUR', 'PROCEDURE', 'ERRMSG'])

# # Print the first few rows of the DataFrame
# print(df.head())

# # Save DataFrame to CSV
# df.to_csv('error_log.csv', index=False)
# Out:
#         PARID TAXYR JUR                      PROCEDURE ERRMSG
# 0  1000110014  2021  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 1  1000110014  2021  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 2  1000161437  2016  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 3  1000161547  2015  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
# 4  1000161555  2016  65  IASW_EXAPP_VAL.VAL_EXCODE_NYC      I
